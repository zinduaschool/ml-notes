# %% [markdown]
# # 1 - Introduction

# %% [markdown]
# # 2-Importing Libries and Data

# %% [markdown]
# # 3 - EDA

# %% [markdown]
# ### 3.1 - Missingness

# %% [markdown]
# ### 3.2 - Outliers

# %% [markdown]
# ### 3.3 - Duplicates

# %% [markdown]
# ### 3.3 - Distribution of My data
# - Gaussian/Normal
# - Normal
# - Binomial
# - Poisson
# - Cuachy - Reimman
# - Kolmogrov Smirnov

# %% [markdown]
# ### 3.4 Multicollinearity
# - Heatmap
# - How does it affect certain models

# %% [markdown]
# ### 3.5 Linear Separability
# For classification problems. You can use random features and a pairplot - with hue as the class, to get an intuition

# %% [markdown]
# # 4 - Data preprocessing
# - Encoding
# - Winsorization/Outlier Handling
# - Scale (Robust Scaler, MinMax Scaler, StandardadScaler)
# - Binning/Grouping
# - Featrue Extraction - Creating features from existing ones
# - Class Balancing - For classification cases.

# %% [markdown]
# # 5 - Model Selection

# %% [markdown]
# - Split your data into training and testing cases
# - Use the training cases to form validation and training sets then run cross validation to get a more realistic picture of your model performance accross variety of unseen data.

# %% [markdown]
# # 6 - Error Analysis and Tuning

# %% [markdown]
# # 7 - Using and Saving the Model

# %% [markdown]
# ## General Notes
# - Ensure you state your problem statement elaborately at the start of the notebook
# - Use the notebook to add insight/deductions in between the code blocks, i.e Explain why one model performed better than the other, etc. What will you be doing in the next steps.
# - The choice of your models, should be determined by the distribution of your features, and of course the problem whether it is a regression or classification problem.
